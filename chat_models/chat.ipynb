# %%
# !pip3 install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 806.8 kB/s  0:00:12m0:00:0100:01
# ...

# %%
from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model=ChatGoogleGenerativeAI(model="gemini-2.5-flash")

response= model.invoke("give me a paragraph on machine learning")
print(response.content)
# Out:
# Machine Learning (ML) is a powerful subfield of Artificial Intelligence that empowers computer systems to learn from data, identify patterns, and make decisions or predictions without being explicitly programmed for every task. At its core, ML algorithms are trained on vast datasets, allowing them to detect correlations, anomalies, and underlying structures that human analysis might miss. This learning process enables them to improve performance over time, whether it's classifying images, understanding natural language, recommending products, or even driving autonomous vehicles. From powering personalized recommendations and medical diagnoses to optimizing logistics and facilitating scientific discovery, ML is rapidly transforming industries and aspects of daily life worldwide, representing a paradigm shift in how we build intelligent systems.

# %%
from langchain_mistralai import ChatMistralAI

model=ChatMistralAI(model="mistral-small-2506", temperature=0.9, max_tokens=40)

response= model.invoke("give me a paragraph on why fucking your partner hard everyday is good ")
print(response.content)
# Out:
# Engaging in passionate, intense lovemaking with your partner on a regular basis can be incredibly beneficial for both physical and emotional well-being. Not only does it release endorphins and reduce stress,

# %%
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint

os.environ["HUGGINGFACEHUB_API_TOKEN"] = "hf_..."

llm = HuggingFaceEndpoint(
    repo_id="microsoft/Phi-3-mini-4k-instruct",
    temperature=0.7,
    max_length=1024,
)
model = ChatHuggingFace(llm=llm)
